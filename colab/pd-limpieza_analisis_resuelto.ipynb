# %% [markdown]
# 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 ⚪ ⚪ ⚪ ⚪ ⚪ ⚪ ⚪ ⚪ ⚪ 🟡 🟡 🟡 🟡 ⚪ ⚪ ⚪ ⚪ ⚪ ⚪ ⚪ ⚪ 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵
# ## 🧹 Limpieza de datos 🧹
#
# > # **⚽ MESSI ⚽**
# > ![messiKFC](https://img.europapress.es/fotoweb/fotonoticia_20211124180450_420.jpg)
#
#
#
# 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 ⚪ ⚪ ⚪ ⚪ ⚪ ⚪ ⚪ ⚪ ⚪ 🟡 🟡 🟡 🟡 ⚪ ⚪ ⚪ ⚪ ⚪ ⚪ ⚪ ⚪ 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵

# %% [markdown]
# ##**🧹 Importamos las librerias que vamos a utilizar**

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %% [markdown]
# ## **🧹Abrimos el dataset con los que vamos a trabajar.**
# Cuando hablamos de **Dataset**, nos referimos a un conjunto de datos (se pueden encontrar en diferentes formatos: CSV, PARQUET, JSON, etc...)
# ##En nuestro caso, dicho data set se encuentran en formato CSV.
# CSV es un archivo de texto que contiene datos separados por coma y nos permite guardar los datos en un formato de tabla estructurada.
# Cada regitro está separado por un salto de línea.
#
# #Ejemplo:
# ![csvEjemplo](https://3.bp.blogspot.com/-53Ahq0v3ehw/Xe_fwe_CDaI/AAAAAAAAAhk/J2y4eQinue8likCs8W7t-IXw_n5by3vuQCLcBGAsYHQ/w1200-h630-p-k-no-nu/archivo%2Bcsv.PNG)

# %% [markdown]
# Nuestro conjunto de datos lo vamos a abrir desde GIT HUB: [MESSI.CSV](https://github.com/cristiandarioortegayubro/base/tree/main/dataset)
# ~~~markdown
# https://github.com/cristiandarioortegayubro/base/tree/main/dataset
# ~~~
# ![MessiDelfin](https://resizer.glanacion.com/resizer/OulWmylUzQWQJW7Dync3QR-N4bI=/768x0/filters:format(webp):quality(80)/cloudfront-us-east-1.images.arcpublishing.com/lanacionar/GKKP4CIEWNDLBP3PPSWHCBPR3Y.jpg)

# %%
messi= pd.read_csv("https://raw.githubusercontent.com/CPazL/clase-pandasPython/main/messiSucio.csv")

# %% [markdown]
# 🧹 Para ver todo el contenido de una columna

# %%
messi
# Out:
#             Tournament     Matchday      Date Venue          Club  \
# 0              LaLiga            34    5/1/05  Home  FC Barcelona
# 1    Champions League   Group Stage   11/2/05  Home  FC Barcelona
# 2              LaLiga            13  11/27/05  Home  FC Barcelona
# 3              LaLiga            19   1/15/06  Home  FC Barcelona
# 4              LaLiga            20   1/22/06  Home  FC Barcelona
# ..                 ...          ...       ...   ...           ...
# 743                NaN          NaN       NaN   NaN           NaN
# 744                NaN          NaN       NaN   NaN           NaN
# 745                NaN          NaN       NaN   NaN           NaN
# 746                NaN          NaN       NaN   NaN           NaN
# 747                NaN          NaN       NaN   NaN           NaN
#
#                  Opponent Result Position Minute When Scored  \
# 0       Albacete Balompié    2:0       CF  90'+1         2:0
# ...

# %% [markdown]
# 🧹 Dimensiones de nuestro archivo

# %%
messi.shape
# Out:
# (748, 13)

# %%
messi.shape[0]
# Out:
# 748

# %%
messi.shape[1]
# Out:
# 13

# %% [markdown]
# 🧹Vemos las primeras 5 filas

# %%
messi.head()
# Out:
#               Torneo      Jornada      Fecha Evento          Club  \
# 0            LaLiga            34 2005-05-01   Home  FC Barcelona
# 1  Champions League   Group Stage 2005-11-02   Home  FC Barcelona
# 2            LaLiga            13 2005-11-27   Home  FC Barcelona
# 3            LaLiga            19 2006-01-15   Home  FC Barcelona
# 4            LaLiga            20 2006-01-22   Home  FC Barcelona
#
#                Oponente Resultado Posición Minuto Momento de anotación  \
# 0     Albacete Balompié       2:0       CF  90'+1                  2:0
# 1  Panathinaikos Athens       5:0       RW    34'                  3:0
# 2      Racing Santander       4:1       RW    51'                  2:0
# 3       Athletic Bilbao       2:1       RW    50'                  2:1
# 4      Deportivo Alavés       2:0       CF    82'                  2:0
#
#         Tipo de gol          Asistente   año  resultado_equipo  \
# 0  Left-footed shot  Ronaldinho Gaúcho  2005                 2
# ...

# %% [markdown]
# 🧹 Podemos cambiar los nombres de las columnas a español para visualizar mejor los datos

# %%
messi.rename(columns={'Tournament':'Torneo'}, inplace=True)
messi.rename(columns={'Matchday':'Jornada'}, inplace=True)
messi.rename(columns={'Date':'Fecha'}, inplace=True)
messi.rename(columns={'Venue':'Evento'}, inplace=True)
messi.rename(columns={'Opponent':'Oponente'}, inplace=True)
messi.rename(columns={'Result':'Resultado'}, inplace=True)
messi.rename(columns={'Position':'Posición'}, inplace=True)
messi.rename(columns={'Minute':'Minuto'}, inplace=True)
messi.rename(columns={'Opponent':'Oponente'}, inplace=True)
messi.rename(columns={'When Scored':'Momento de anotación'}, inplace=True)
messi.rename(columns={'Goal Type':'Tipo de gol'}, inplace=True)
messi.rename(columns={'Assist':'Asistente'}, inplace=True)

# %% [markdown]
# 🧹 Visualizamos tipo de datos y cantidad de elementos no nulos por columna

# %%
messi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 690 entries, 0 to 689
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Torneo                690 non-null    string
#  1   Jornada               690 non-null    string
#  2   Fecha                 690 non-null    datetime64[ns]
#  3   Evento                690 non-null    string
#  4   Club                  690 non-null    string
#  5   Oponente              690 non-null    string
#  6   Resultado             690 non-null    string
#  7   Posición              690 non-null    string
#  8   Minuto                690 non-null    string
#  9   Momento de anotación  690 non-null    string
#  10  Tipo de gol           690 non-null    string
#  11  Asistente             690 non-null    string
#  12  año                   690 non-null    int64
#  13  resultado_equipo      690 non-null    int64
#  14  resultado_oponente    690 non-null    int64
# ...

# %%
messi.dtypes
# Out:
# Torneo                          string
# Jornada                         string
# Fecha                   datetime64[ns]
# Evento                          string
# Club                            string
# Oponente                        string
# Resultado                       string
# Posición                        string
# Minuto                          string
# Momento de anotación            string
# Tipo de gol                     string
# Asistente                       string
# año                              int64
# resultado_equipo                 int64
# resultado_oponente               int64
# minuto_partido                   int64
# minuto_extra                    object
# dtype: object

# %% [markdown]
# 🧹 Si hay datos que no corresponden con el contenido del dato, debemos cambiarlos.
#
# > **Podemos comenzar por los que no contienen diferentes tipos de datos como números y fechas, o números y strings **

# %%
messi.head()
# Out:
#               Torneo      Jornada     Fecha Evento          Club  \
# 0            LaLiga            34    5/1/05   Home  FC Barcelona
# 1  Champions League   Group Stage   11/2/05   Home  FC Barcelona
# 2            LaLiga            13  11/27/05   Home  FC Barcelona
# 3            LaLiga            19   1/15/06   Home  FC Barcelona
# 4            LaLiga            20   1/22/06   Home  FC Barcelona
#
#                Oponente Resultado Posición Minuto Momento de anotación  \
# 0     Albacete Balompié       2:0       CF  90'+1                  2:0
# 1  Panathinaikos Athens       5:0       RW    34'                  3:0
# 2      Racing Santander       4:1       RW    51'                  2:0
# 3       Athletic Bilbao       2:1       RW    50'                  2:1
# 4      Deportivo Alavés       2:0       CF    82'                  2:0
#
#         Tipo de gol          Asistente            Pareja
# 0  Left-footed shot  Ronaldinho Gaúcho  Antonela Rocuzzo
# ...

# %%
messi['Minuto'].unique()
# Out:
# array(["90'+1", "34'", "51'", "50'", "82'", "75'", "83'", "42'", "84'",
#        "59'", "36'", "89'", "80'", "11'", "28'", "86'", "45'", "29'",
#        "39'", "43'", "57'", "72'", "79'", "5'", "10'", "66'", "19'",
#        "41'", "81'", "58'", "18'", "44'", "70'", "85'", "90'", "87'",
#        "90'+2", "8'", "4'", "61'", "49'", "78'", "21'", "76'", "65'",
#        "30'", "31'", "40'", "26'", "9'", "38'", "23'", "35'", "55'",
#        "68'", "15'", "90'+3", "63'", "25'", "64'", "110'", "54'", "7'",
#        "56'", "13'", "67'", "37'", "88'", "32'", "16'", "74'", "3'",
#        "22'", "12'", "20'", "46'", "73'", "33'", "77'", "52'", "53'",
#        "69'", "24'", "45'+2", "17'", "71'", "27'", "60'", "48'", "6'",
#        "62'", "45'+1", "90'+4", "47'", "14'", "45'+4", nan], dtype=object)

# %%
messi['Momento de anotación'].unique()
# Out:
# array(['2:0', '3:0', '2:1', '0:2', '0:3', '1:0', '5:1', '1:2', '1:1',
#        '3:1', '2:2', '3:3', '0:4', '0:1', '0:5', '2:3', '1:5', '1:6',
#        '1:3', '4:1', '2:5', '5:2', '4:0', '1:4', '0:7', '3:2', '5:0',
#        '8:0', '4:2', '7:0', '2:4', '3:5', '6:0', '3:4', '0:6', '6:1',
#        '6:2', '4:3', nan], dtype=object)

# %%
messi['Fecha'].unique()
# Out:
# array(['5/1/05', '11/2/05', '11/27/05', '1/15/06', '1/22/06', '1/29/06',
#        '2/1/06', '2/18/06', '8/28/06', '9/9/06', '9/27/06', '10/15/06',
#        '3/10/07', '3/17/07', '3/31/07', '4/18/07', '5/20/07', '6/9/07',
#        '6/17/07', '9/19/07', '9/22/07', '9/26/07', '9/29/07', '10/2/07',
#        '10/7/07', '10/28/07', '11/7/07', '11/24/07', '11/27/07',
#        '2/20/08', '2/24/08', '5/4/08', '9/13/08', '9/21/08', '9/27/08',
#        '10/1/08', '10/4/08', '10/22/08', '11/1/08', '11/4/08', '11/12/08',
#        '11/16/08', '11/26/08', '11/29/08', '12/13/08', '1/6/09',
#        '1/11/09', '1/17/09', '1/24/09', '2/1/09', '3/1/09', '3/4/09',
#        '3/7/09', '3/11/09', '3/22/09', '4/8/09', '4/18/09', '4/25/09',
#        '5/2/09', '5/13/09', '5/27/09', '8/23/09', '9/12/09', '9/19/09',
#        '9/22/09', '9/29/09', '10/25/09', '11/7/09', '11/10/09', '12/5/09',
#        '12/9/09', '12/16/09', '12/19/09', '1/10/10', '1/16/10', '1/23/10',
# ...

# %% [markdown]
# > Convertimos los tipos de datos

# %%
messi['Torneo'] = messi['Torneo'].astype('string')
messi['Jornada'] = messi['Jornada'].astype('string')
messi['Fecha'] = pd.to_datetime(messi['Fecha'])
messi['Evento'] = messi['Evento'].astype('string')
messi['Club'] = messi['Club'].astype('string')
messi['Oponente'] = messi['Oponente'].astype('string')
messi['Resultado'] = messi['Resultado'].astype('string')
messi['Posición'] = messi['Posición'].astype('string')
messi['Tipo de gol'] = messi['Tipo de gol'].astype('string')
messi['Asistente'] = messi['Asistente'].astype('string')
messi['Pareja'] = messi['Pareja'].astype('string')
messi['Minuto'] = messi['Minuto'].astype('string')
messi['Momento de anotación'] = messi['Momento de anotación'].astype('string')

# %%
messi.head()
# Out:
#               Torneo      Jornada      Fecha Evento          Club  \
# 0            LaLiga            34 2005-05-01   Home  FC Barcelona
# 1  Champions League   Group Stage 2005-11-02   Home  FC Barcelona
# 2            LaLiga            13 2005-11-27   Home  FC Barcelona
# 3            LaLiga            19 2006-01-15   Home  FC Barcelona
# 4            LaLiga            20 2006-01-22   Home  FC Barcelona
#
#                Oponente Resultado Posición Minuto Momento de anotación  \
# 0     Albacete Balompié       2:0       CF  90'+1                  2:0
# 1  Panathinaikos Athens       5:0       RW    34'                  3:0
# 2      Racing Santander       4:1       RW    51'                  2:0
# 3       Athletic Bilbao       2:1       RW    50'                  2:1
# 4      Deportivo Alavés       2:0       CF    82'                  2:0
#
#         Tipo de gol          Asistente            Pareja
# 0  Left-footed shot  Ronaldinho Gaúcho  Antonela Rocuzzo
# ...

# %%
messi.dtypes
# Out:
# Torneo                          string
# Jornada                         string
# Fecha                   datetime64[ns]
# Evento                          string
# Club                            string
# Oponente                        string
# Resultado                       string
# Posición                        string
# Minuto                          string
# Momento de anotación            string
# Tipo de gol                     string
# Asistente                       string
# Pareja                          string
# dtype: object

# %% [markdown]
# 🧹 El método **describe()** devuelve la descripción de los datos en el DataFrame.
#
# Si el DataFrame contiene datos numéricos, la descripción contiene esta información para cada columna:
#
# >**count**: el número de valores no vacíos.
#
# >**unique**: valor único.
#
# >**top**: El elemento que más se repite.
#
# >**freq**: La cantidad de veces que se repite dicho elemento

# %%
messi.describe()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   """Entry point for launching an IPython kernel.
#          Torneo      Jornada                Fecha Evento          Club  \
# count       712          712                  712    712           712
# unique        8           46                  445      2             2
# top     LaLiga   Group Stage  2022-08-06 00:00:00   Home  FC Barcelona
# freq        474           79                    6    420           672
# first       NaN          NaN  2005-05-01 00:00:00    NaN           NaN
# last        NaN          NaN  2022-10-01 00:00:00    NaN           NaN
#
#           Oponente Resultado Posición Minuto Momento de anotación  \
# ...

# %% [markdown]
# Divisamos porcentajes de nulos por cada columna

# %%
messi.isna()

# %%
(messi.isna().sum()*100/messi.shape[0]).sort_values(ascending = False)
# Out:
# Torneo                  4.812834
# Jornada                 4.812834
# Fecha                   4.812834
# Evento                  4.812834
# Club                    4.812834
# Oponente                4.812834
# Resultado               4.812834
# Posición                4.812834
# Minuto                  4.812834
# Momento de anotación    4.812834
# Tipo de gol             4.812834
# Asistente               4.812834
# Pareja                  4.812834
# dtype: float64

# %% [markdown]
# ![messicara](https://st1.uvnimg.com/dims4/default/c03f1d8/2147483647/resize/420x620%3E/quality/75/?url=http%3A%2F%2Fuvn-brightspot.s3.amazonaws.com%2F41%2Fac%2F2c6b28844ac5bf80ffed73bac678%2F1-messi.jpg)

# %% [markdown]
# 🧹 Eliminamos las filas que tienen todos nulos

# %%
messi.dropna(axis=0, inplace= True, how='all')
messi.shape
# Out:
# (690, 17)

# %%
(messi.isna().sum()*100/messi.shape[0]).sort_values(ascending = False)
# Out:
# Torneo                  0.0
# Jornada                 0.0
# Fecha                   0.0
# Evento                  0.0
# Club                    0.0
# Oponente                0.0
# Resultado               0.0
# Posición                0.0
# Minuto                  0.0
# Momento de anotación    0.0
# Tipo de gol             0.0
# Asistente               0.0
# Pareja                  0.0
# dtype: float64

# %% [markdown]
# 🧹 Eliminamos las filas que tienen un porcentaje de NaN mayor al 80%

# %%
messi.dropna(axis=0, inplace= True, thresh=int(messi.shape[1]*0.8))
messi.shape
# Out:
# (690, 17)

# %% [markdown]
# 🧹 Eliminamos las columnas completas que no nos van a servir para nuestro análisis o que no tienen información relevante

# %%
messi.drop(['Pareja'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-61-729f8dd1ec0a> in <module>
# ----> 1 messi.drop(['Pareja'], axis=1, inplace=True)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
# ...

# %% [markdown]
# ![messillora](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRZI0G5rhExnPw67l4IfvyMXYYDrEYwBE--INK7TA-GEWdAyDRZ2bZJqK61WnDp8t1t1x0&usqp=CAU)

# %%
messi.shape
# Out:
# (712, 12)

# %%
messi.sort_values('Resultado')
# Out:
#        Torneo Jornada      Fecha Evento                 Club  \
# 613   LaLiga       15 2019-12-01   Away         FC Barcelona
# 407   LaLiga       37 2015-05-17   Away         FC Barcelona
# 710  Ligue 1        8 2022-09-18   Away  Paris Saint-Germain
# 688  Ligue 1        8 2022-09-18   Away  Paris Saint-Germain
# 348   LaLiga       31 2014-03-29   Away         FC Barcelona
# ..        ...     ...        ...    ...                  ...
# 186   LaLiga        4 2011-09-17   Home         FC Barcelona
# 188   LaLiga        4 2011-09-17   Home         FC Barcelona
# 187   LaLiga        4 2011-09-17   Home         FC Barcelona
# 554   LaLiga        3 2018-09-02   Home         FC Barcelona
# 555   LaLiga        3 2018-09-02   Home         FC Barcelona
#
#                    Oponente Resultado Posición Minuto Momento de anotación  \
# 613      Atlético de Madrid       0:1       RW    86'                  0:1
# 407      Atlético de Madrid       0:1       RW    65'                  0:1
# ...

# %% [markdown]
# 🧹 Eliminamos columnas duplciadas.
# > Si este es el caso, se quedará con una de las dos filas

# %%
messi.shape
# Out:
# (712, 12)

# %%
messi= messi.drop_duplicates()

# %%
messi.shape
# Out:
# (690, 12)

# %% [markdown]
# 🧹 Separamos datos que nos resulten útiles durante el análisis.
# Por ejemplo: Podemos crear una columna solo con el año.

# %%
messi['año'] = messi['Fecha'].dt.year
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
messi.shape
# Out:
# (690, 13)

# %% [markdown]
# 🧹 Separamos la columna resultado: Resultado_oponente y Resultado_equipo

# %%
messi['resultado_equipo']=0
messi['resultado_oponente']=0
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
messi.tail()
# Out:
#                 Torneo      Jornada      Fecha Evento                 Club  \
# 685           Ligue 1             1 2022-08-06   Away  Paris Saint-Germain
# 686           Ligue 1             3 2022-08-21   Away  Paris Saint-Germain
# 687  Champions League   Group Stage 2022-09-14   Away  Paris Saint-Germain
# 688           Ligue 1             8 2022-09-18   Away  Paris Saint-Germain
# 689           Ligue 1             9 2022-10-01   Home  Paris Saint-Germain
#
#              Oponente Resultado Posición Minuto Momento de anotación  \
# 685  Clermont Foot 63       0:5       CF    86'                  0:5
# 686        LOSC Lille       1:7       AM    27'                  0:2
# 687     Maccabi Haifa       1:3       SS    37'                  1:1
# 688    Olympique Lyon       0:1       AM     5'                  0:1
# 689          OGC Nice       2:1       AM    28'                  1:0
#
#            Tipo de gol        Asistente   año  resultado_equipo  \
# ...

# %%
messi['Resultado'][0].split(sep=':')
# Out:
# ['2', '0']

# %%
def fun_result_equipo(evento, resultado):
  res_sep= resultado.split(sep=':')

  if evento == 'Home':
    return res_sep[0]

  elif evento =='Away': 
    return res_sep[1]

# %%
for i in range(messi.shape[0]):
  messi['resultado_equipo'][i]= fun_result_equipo(messi['Evento'][i], messi['Resultado'][i])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# 🧹 Ahora vamos con los resultados del oponente

# %%
def fun_result_oponent(evento, resultado):
  res_sep= resultado.split(sep=':')

  if evento == 'Home':
    return res_sep[1]

  elif evento =='Away': 
    return res_sep[0]

# %%
for i in range(messi.shape[0]):
  messi['resultado_oponente'][i]= fun_result_oponent(messi['Evento'][i], messi['Resultado'][i])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# 🧹 Vamos a convertir en tipo númerico el minuto del gol

# %%
messi['minuto_partido']=0
messi['minuto_extra']=0

for i in range(messi.shape[0]):
  min_sep= messi['Minuto'][i].split(sep="'")
  messi['minuto_partido'][i]= min_sep[0]
  messi['minuto_extra'][i] = min_sep[1]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
messi.sort_values(ascending = True, by='minuto_partido').head()
# Out:
#               Torneo Jornada      Fecha Evento          Club  \
# 95   Club World Cup    Final 2009-12-19   Away  FC Barcelona
# 0            LaLiga       34 2005-05-01   Home  FC Barcelona
# 660          LaLiga       27 2021-03-15   Home  FC Barcelona
# 173          LaLiga       31 2011-04-09   Home  FC Barcelona
# 191          LaLiga        6 2011-09-24   Home  FC Barcelona
#
#                          Oponente Resultado Posición Minuto  \
# 95   Club Estudiantes de La Plata       1:2       RW   110'
# 0               Albacete Balompié       2:0       CF  90'+1
# 660                     SD Huesca       4:1       AM    90'
# 173                    UD Almería       3:1       CF  90'+1
# 191            Atlético de Madrid       5:0       CF  90'+1
#
#     Momento de anotación       Tipo de gol          Asistente   año  \
# 95                   1:2             Chest         Dani Alves  2009
# 0                    2:0  Left-footed shot  Ronaldinho Gaúcho  2005
# ...

# %% [markdown]
# ## **Los datos limpios nos quedarían algo así:**
#
# >![Messisorprendido](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR-l2cABcbQQdExcMs200SuyI8uOX1J5kUuAOinbbT-If7v4F8Vo-i6zguRGtn2cysK0f8&usqp=CAU)

# %% [markdown]
# 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 ⚪ ⚪ ⚪ ⚪ ⚪ ⚪ ⚪ ⚪ ⚪ 🟡 🟡 🟡 🟡 ⚪ ⚪ ⚪ ⚪ ⚪ ⚪ ⚪ ⚪ 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵
# # 🔎 **Análisis de datos**
# A ver que encontramos...
# ![Messialegre](https://i.pinimg.com/564x/be/6b/10/be6b10b0b71981f299de20228ec594a1.jpg)

# %% [markdown]
# 🔎 ¿Mete más goles en primer o segundo tiempo?
#
# ![MESIJUEGO](https://media.tycsports.com/files/2022/04/19/417187/messi-meme-en-efootball-2022_w416.webp)

# %%
primer_tiempo=0
segundo_tiempo=0
extra_1T=0
extra_2T=0

for i in range(messi.shape[0]):

  if messi['minuto_partido'][i] <45 :
      primer_tiempo+=1
  elif messi['minuto_partido'][i]>45 and messi['minuto_partido'][i]<90 :
      segundo_tiempo+=1
  elif messi['minuto_partido'][i]==45 and messi['minuto_extra'][i]!=0:
      extra_1T+=1
  elif messi['minuto_partido'][i]==45 and messi['minuto_extra'][i]==0:
    primer_tiempo+=1
  elif messi['minuto_partido'][i] == 90 and messi['minuto_extra'][i] == 0:
    segundo_tiempo+=1
  elif messi['minuto_partido'][i] < 90 :
    extra_2T+=1
  else:
    extra_2T+=1

print('Porcentaje de goles en el primer tiempo:', (primer_tiempo/messi.shape[0]) * 100)
print('Porcentaje de goles en el Primer tiempo extra:', (extra_1T/messi.shape[0]) * 100)
print(' ')
print('Porcentaje de goles en el Segundo tiempo:', (segundo_tiempo/messi.shape[0]) * 100)
print('Porcentaje de goles en el Segundo tiempo extra:', (extra_2T/messi.shape[0]) * 100)
# Out:
# Porcentaje de goles en el primer tiempo: 41.449275362318836
# Porcentaje de goles en el Primer tiempo extra: 2.608695652173913
#
# Porcentaje de goles en el Segundo tiempo: 50.289855072463766
# Porcentaje de goles en el Segundo tiempo extra: 5.6521739130434785

# %% [markdown]
# **🔎 ¿Cuantos goles hizo Messi por partido? (Debemos sacar el promedio)**
#
# > En está parte debemos agrupar los registros de goles por partido. Pueden pasar que dos goles o más se realicen en un mismo partido
# ![MESSIRVE](https://i.redd.it/wlopp34hn5861.jpg)

# %%
prom_agrupados= messi.groupby(by=['Fecha','Jornada']).count().mean()

# %%
print("En los partido que hace goles el promedio de goles por partido por Messi es de : ", prom_agrupados[0])
# Out:
# En los partido que hace goles el promedio de goles por partido por Messi es de :  1.550561797752809

# %% [markdown]
# 🔎 Total de goles por año

# %%
(messi.groupby(by=['año']).count()).loc[:, 'Jornada']
# Out:
# año
# 2005     3
# 2006    10
# 2007    25
# 2008    20
# 2009    38
# 2010    58
# 2011    55
# 2012    79
# 2013    39
# 2014    50
# 2015    48
# 2016    51
# 2017    50
# 2018    47
# 2019    45
# 2020    26
# 2021    34
# 2022    12
# Name: Jornada, dtype: int64

# %% [markdown]
# 🔎 Promedio de de goles por tipo de movimiento

# %%
messiGoles= messi.groupby(by=['Tipo de gol']).count()
messiGoles = messiGoles.loc[:, 'Resultado']
messiGoles
# Out:
# Tipo de gol
# Chest                       1
# Counter attack goal         1
# Deflected shot on goal      2
# Direct free kick           51
# Header                     24
# Left-footed shot          425
# Long distance kick          1
# Not Applicable              1
# Penalty                    84
# Penalty rebound             3
# Right-footed shot          83
# Solo run                    4
# Tap-in                     10
# Name: Resultado, dtype: int64

# %% [markdown]
# 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 ⚪ ⚪ ⚪ ⚪ ⚪ ⚪ ⚪ ⚪ ⚪ 🟡 🟡 🟡 🟡 ⚪ ⚪ ⚪ ⚪ ⚪ ⚪ ⚪ ⚪ 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵
# ###**ACTIVIDAD** 📓
# ![242f9a68be04722994bf1a7071178311.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Elegir uno d elos siguientes datasets:
#
#
# > RONALDO:
#
# > NEYMAR:
#
# > LEWANDOWSKI:
#
#
#
# Realizar limpieza:
#
#
# 1.  Importar librerías.
# 2.  Leer archivo CSV como dataframe.
# 3.  Ver dimensiones del Dataframe (cantidad de columnas y filas).
# 4.  Ver los primeros 11 registros (filas).
# 5.  Cambiar tipos de datos según considere.
# 6.  Cambiar nombres de columnas a español.
# 7.  Borrar columna según corresponda
#           Ronaldo: Madre
#           Neymar: Estatura
#           Lewandoski: Nacionalidad
# 8.  Borrar registros duplicados.
# 9.  Crear la columna de año
# 9.  crear columnas que considere pertinente.
#
#
# Analisis:
#
# 1. Calcular el total de goles  registrados hasta la fecha
# 2. Calcular el promedio de goles por Torneo.
# 3. Calcular porcentaje de goles realizados como visitante(Away) y local(Home) con respecto al total de goles.
# 4. A que oponente le metió más goles.
# 5. Contra que oponente jugó más fechas.
# 6. Realiza un caso de uso a gusto , osea analiza lo que gustes. Es libre!

# %% [markdown]
# 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 ⚪ ⚪ ⚪ ⚪ ⚪ ⚪ ⚪ ⚪ ⚪ 🟡 🟡 🟡 🟡 ⚪ ⚪ ⚪ ⚪ ⚪ ⚪ ⚪ ⚪ 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵
#
# Podemos descargar los archivos limpios en nuestra compu

# %%
messi.to_csv('messiLimpio.csv')

# %%
from google.colab import files
files.download('messiLimpio.csv')

# %% [markdown]
# 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 ⚪ ⚪ ⚪ ⚪ ⚪ ⚪ ⚪ ⚪ ⚪ 🟡 🟡 🟡 🟡 ⚪ ⚪ ⚪ ⚪ ⚪ ⚪ ⚪ ⚪ 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵
# **GRACIAS POR SU ATENCIÓN!**
#
#
# > Y no te olvides de lo más importante: **CARTAS ANTI MUFA**
#
#
# >>![carta1](https://pbs.twimg.com/media/FHaFH1nXEAIZ4ZW.jpg)
#
#
# >>![carta2](https://pbs.twimg.com/media/FUWGdmqWIAAKlUk.jpg)
